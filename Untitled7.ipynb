# %%
import numpy as np

# student_scores is assumed to be a NumPy array (rows = students, columns = subjects)

# Calculate average score for each subject
avg_scores = np.mean(student_scores, axis=0)

subjects = ["Math", "Science", "English", "History"]

# Print average scores
for i in range(len(subjects)):
    print(subjects[i], "Average:", avg_scores[i])

# Find subject with highest average score
highest_subject = subjects[np.argmax(avg_scores)]
print("/content/student_scores - student_scores.csv", highest_subject)
# Out:
# Math Average: 81.96875
# Science Average: 82.5625
# English Average: 82.96875
# History Average: 82.875
# /content/student_scores - student_scores.csv English
